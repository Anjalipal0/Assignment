# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('delivery_time.csv')

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
data.plot(y = 'Delivery Time',kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(data['Delivery Time'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1620\2217253749.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delivery Time'])
# <Axes: xlabel='Delivery Time', ylabel='Density'>

# %%
sns.distplot(data['Sorting Time'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1620\3932129489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sorting Time'])
# <Axes: xlabel='Sorting Time', ylabel='Density'>

# %%
data.drop_duplicates()
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data = data.drop_duplicates()

# %%
data.plot('Delivery Time','Sorting Time',kind = 'scatter')
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
sns.scatterplot(x =data['Delivery Time'],y = data['Sorting Time'])
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
y = data['Sorting Time']

# %%
X = data['Delivery Time']

# %%
import statsmodels.api as sm

# %%
sm.OLS(y,X)

# %%
ols = sm.OLS(y,X)

# %%
ols.fit()

# %%
model = ols.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           Sorting Time   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              424.5
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):                    6.12e-15
# Time:                        16:19:35   Log-Likelihood:                         -37.082
# No. Observations:                  21   AIC:                                      76.16
# Df Residuals:                      20   BIC:                                      77.21
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
data["Delivery Time"][0]
# Out:
# 21.0

# %%
data['Sorting Time'][0]
# Out:
# 10

# %%
sm.add_constant(X)
# Out:
#     const  Delivery Time
# 0     1.0          21.00
# 1     1.0          13.50
# 2     1.0          19.75
# 3     1.0          24.00
# 4     1.0          29.00
# 5     1.0          15.35
# 6     1.0          19.00
# 7     1.0           9.50
# 8     1.0          17.90
# 9     1.0          18.75
# 10    1.0          19.83
# 11    1.0          10.75
# 12    1.0          16.68
# 13    1.0          11.50
# 14    1.0          12.03
# 15    1.0          14.88
# 16    1.0          13.75
# 17    1.0          18.11
# 18    1.0           8.00
# 19    1.0          17.83
# 20    1.0          21.50

# %%
X = sm.add_constant(X)

# %%
ols = sm.OLS(y,X)

# %%
model1 = ols.fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Sorting Time   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           3.98e-06
# Time:                        16:21:23   Log-Likelihood:                -36.839
# No. Observations:                  21   AIC:                             77.68
# Df Residuals:                      19   BIC:                             79.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as smf

# %%
X
# Out:
#     const  Delivery Time
# 0     1.0          21.00
# 1     1.0          13.50
# 2     1.0          19.75
# 3     1.0          24.00
# 4     1.0          29.00
# 5     1.0          15.35
# 6     1.0          19.00
# 7     1.0           9.50
# 8     1.0          17.90
# 9     1.0          18.75
# 10    1.0          19.83
# 11    1.0          10.75
# 12    1.0          16.68
# 13    1.0          11.50
# 14    1.0          12.03
# 15    1.0          14.88
# 16    1.0          13.75
# 17    1.0          18.11
# 18    1.0           8.00
# 19    1.0          17.83
# 20    1.0          21.50

# %%
smf.ols('y~X',drop_cols = X['const'],data = data)

# %%
ols = smf.ols('y~X',drop_cols = X['const'],data = data)

# %%
model2 = ols.fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           3.98e-06
# Time:                        16:22:26   Log-Likelihood:                -36.839
# No. Observations:                  21   AIC:                             77.68
# Df Residuals:                      19   BIC:                             79.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3783      0.567     -0.667      0.513      -1.565       0.808
# ...

# %%
ols = smf.ols('y~X',data = data)

# %%
model2 = ols.fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           3.98e-06
# Time:                        16:22:49   Log-Likelihood:                -36.839
# No. Observations:                  21   AIC:                             77.68
# Df Residuals:                      19   BIC:                             79.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3783      0.567     -0.667      0.513      -1.565       0.808
# ...

# %%
model2.params
# Out:
# Intercept   -0.378337
# X[0]        -0.378337
# X[1]         0.413744
# dtype: float64

# %%
model2.pvalues
# Out:
# Intercept    0.512611
# X[0]         0.512611
# X[1]         0.000004
# dtype: float64

# %%
plt.scatter(data['Delivery Time'],y)

# %%
# %matplotlib notebook

# %%
plt.scatter(data['Delivery Time'],y)
Y = 0.001638*data["Delivery Time"] + 0.155203
plt.plot(data['Delivery Time'],Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(data['Delivery Time'],y)
Y = 0.001638*data["Delivery Time"] + 0.155203
plt.plot(data['Delivery Time'],Y,lw = 4, c = 'orange',label = 'regression line')

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
sns.distplot(data["Sorting Time"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1620\2221179050.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Sorting Time"])
# <Axes: xlabel='Sorting Time', ylabel='Density'>

# %%
data['Sorting Time']>2.6
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# Name: Sorting Time, dtype: bool

# %%
data = data[data['Sorting Time']>2.6]

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 19          17.83             7
# 20          21.50             5

# %%
y = data['Sorting Time']

# %%
X = data['Delivery Time']

# %%
model3 = ols.fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           3.98e-06
# Time:                        16:33:54   Log-Likelihood:                -36.839
# No. Observations:                  21   AIC:                             77.68
# Df Residuals:                      19   BIC:                             79.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3783      0.567     -0.667      0.513      -1.565       0.808
# ...

# %%
plt.scatter(data['Delivery Time'],y)
Y = 0.0013*data["Delivery Time"] + 0.8952
plt.plot(data['Delivery Time'],Y,lw = 4, c = 'orange',label = 'regression line')
plt.show()

# %%
sns.regplot(x ="Delivery Time", y = "Sorting Time",data=data)
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %%
# Finding Coefficient parameters
model.params
# Out:
# Intercept   -0.378337
# X[0]        -0.378337
# X[1]         0.413744
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , model.pvalues
# Out:
# (Intercept   -0.667290
#  X[0]        -0.667290
#  X[1]         6.387447
#  dtype: float64,
#  Intercept    0.512611
#  X[0]         0.512611
#  X[1]         0.000004
#  dtype: float64)

# %%
# Finding Rsquared Values
model.rsquared , model.rsquared_adj
# Out:
# (0.682271474841723, 0.6655489208860242)

# %% [markdown]
# # Model Predictions

# %%
# Manual prediction for say sorting time 5
delivery_time = (6.582734) + (1.649020)*(5)
delivery_time
# Out:
# 14.827834

# %%
# Automatic Prediction for say sorting time 5, 8
new_data=pd.Series([5,8])
new_data
# Out:
# 0    5
# 1    8
# dtype: int64

# %%
data_pred=pd.DataFrame(new_data,columns=['sorting_time'])
data_pred
# Out:
#    sorting_time
# 0             5
# 1             8
