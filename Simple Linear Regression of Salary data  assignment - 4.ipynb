# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Salary_Data.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
dataset.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.plot(y='YearsExperience',kind="hist")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(data.YearsExperience)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_25432\19949586.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.YearsExperience)
# <Axes: xlabel='YearsExperience', ylabel='Frequency'>

# %%
data.drop_duplicates()
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data = data.drop_duplicates()

# %%
data.plot('YearsExperience','Salary',kind = 'scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.scatterplot(x =data['YearsExperience'],y = data['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
y = data['Salary']

# %%
X = data['YearsExperience']

# %%
import statsmodels.api as sm

# %%
sm.OLS(y,X)

# %%
ols = sm.OLS(y,X)

# %%
ols.fit()

# %%
model = ols.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              1048.
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):                    2.56e-24
# Time:                        16:06:04   Log-Likelihood:                         -327.28
# No. Observations:                  30   AIC:                                      656.6
# Df Residuals:                      29   BIC:                                      658.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
data["YearsExperience"][0]
# Out:
# 1.1

# %%
data['Salary'][0]
# Out:
# 39343.0

# %%
sm.add_constant(X)
# Out:
#     const  YearsExperience
# 0     1.0              1.1
# 1     1.0              1.3
# 2     1.0              1.5
# 3     1.0              2.0
# 4     1.0              2.2
# 5     1.0              2.9
# 6     1.0              3.0
# 7     1.0              3.2
# 8     1.0              3.2
# 9     1.0              3.7
# 10    1.0              3.9
# 11    1.0              4.0
# 12    1.0              4.0
# 13    1.0              4.1
# 14    1.0              4.5
# 15    1.0              4.9
# 16    1.0              5.1
# 17    1.0              5.3
# 18    1.0              5.9
# 19    1.0              6.0
# 20    1.0              6.8
# 21    1.0              7.1
# 22    1.0              7.9
# 23    1.0              8.2
# 24    1.0              8.7
# 25    1.0              9.0
# 26    1.0              9.5
# 27    1.0              9.6
# 28    1.0             10.3
# 29    1.0             10.5

# %%
X = sm.add_constant(X)

# %%
ols = sm.OLS(y,X)

# %%
model1 = ols.fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           1.14e-20
# Time:                        16:06:06   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as smf

# %%
X
# Out:
#     const  YearsExperience
# 0     1.0              1.1
# 1     1.0              1.3
# 2     1.0              1.5
# 3     1.0              2.0
# 4     1.0              2.2
# 5     1.0              2.9
# 6     1.0              3.0
# 7     1.0              3.2
# 8     1.0              3.2
# 9     1.0              3.7
# 10    1.0              3.9
# 11    1.0              4.0
# 12    1.0              4.0
# 13    1.0              4.1
# 14    1.0              4.5
# 15    1.0              4.9
# 16    1.0              5.1
# 17    1.0              5.3
# 18    1.0              5.9
# 19    1.0              6.0
# 20    1.0              6.8
# 21    1.0              7.1
# 22    1.0              7.9
# 23    1.0              8.2
# 24    1.0              8.7
# 25    1.0              9.0
# 26    1.0              9.5
# 27    1.0              9.6
# 28    1.0             10.3
# 29    1.0             10.5

# %%
smf.ols('y~X',drop_cols = X['const'],data = data)

# %%
ols = smf.ols('y~X',drop_cols = X['const'],data = data)

# %%
model2 = ols.fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           1.14e-20
# Time:                        16:06:08   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.29e+04   1136.527     11.347      0.000    1.06e+04    1.52e+04
# ...

# %%
ols = smf.ols('y~X',data = data)

# %%
model2 = ols.fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           1.14e-20
# Time:                        16:06:09   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.29e+04   1136.527     11.347      0.000    1.06e+04    1.52e+04
# ...

# %%
model2.params
# Out:
# Intercept    12896.100099
# X[0]         12896.100099
# X[1]          9449.962321
# dtype: float64

# %%
model2.pvalues
# Out:
# Intercept    5.511950e-12
# X[0]         5.511950e-12
# X[1]         1.143068e-20
# dtype: float64

# %%
plt.scatter(data['YearsExperience'],y)

# %%
# %matplotlib notebook

# %%
plt.scatter(data['YearsExperience'],y)
Y = 0.001638*data["YearsExperience"] + 0.155203
plt.plot(data['YearsExperience'],Y)

# %%
plt.scatter(data['YearsExperience'],y)
Y = 0.001638*data["YearsExperience"] + 0.155203
plt.plot(data['YearsExperience'],Y,lw = 4, c = 'orange',label = 'regression line')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sns.distplot(data["Salary"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_25432\3726928974.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Salary"])
# <Axes: xlabel='Salary', ylabel='Salary'>

# %%
data['Salary']>2.6
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# Name: Salary, dtype: bool

# %%
data = data[data['Salary']>2.6]

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y = data['Salary']

# %%
X = data['YearsExperience']

# %%
ols = smf.ols('y~X',data = data)

# %%
model3 = ols.fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 25 Dec 2023   Prob (F-statistic):           1.14e-20
# Time:                        16:06:12   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# ...

# %%
plt.scatter(data['YearsExperience'],y)
Y=0.0013*data["YearsExperience"]+0.8952
plt.plot(data['YearsExperience'],Y,lw = 4,c='orange',label='regression line')
plt.show()

# %%
sns.regplot(x ="YearsExperience",y="Salary",data=data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>
